# %%
from pydub import AudioSegment, audio_segment
from pydub.playback import play
import os
from afm.processing import *

# %%
filepath = "/home/kamil-grunwald/Downloads/audio/"
filetype = "aac"
files = os.listdir(filepath)
files = [f for f in files if f.endswith(filetype)]

# %%
sample = AudioSegment.from_file(os.path.join(filepath, files[0]), format=filetype)

# %%
play(sample)
# Out:
# Input #0, wav, from '/tmp/tmp8guv52as.wav':   0KB sq=    0B f=0/0
#   Duration: 00:00:56.49, bitrate: 1536 kb/s
#   Stream #0:0: Audio: pcm_s16le ([1][0][0][0] / 0x0001), 48000 Hz, 2 channels, s16, 1536 kb/s
#    4.06 M-A: -0.000 fd=   0 aq=  188KB vq=    0KB sq=    0B f=0/0
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 play(sample)
#
# File ~/miniconda3/envs/acoustic-env/lib/python3.14/site-packages/pydub/playback.py:71, in play(audio_segment)
#      68 else:
#      69     return
# ---> 71 _play_with_ffplay(audio_segment)
#
# File ~/miniconda3/envs/acoustic-env/lib/python3.14/site-packages/pydub/playback.py:16, in _play_with_ffplay(seg)
#      14 with NamedTemporaryFile("w+b", suffix=".wav") as f:
#      15     seg.export(f.name, "wav")
# ---> 16     subprocess.call([PLAYER, "-nodisp", "-autoexit", "-hide_banner", f.name])
#
# ...

# %%
audio, sample_rate = load()

# %%
plot_spectrogram(audio, sample_rate)
